# %%
import pandas as pd

# %%
# READ FILE
df=pd.read_csv("C:\\Users\\hraha_8xjyrze\\Downloads\\archive\\orders.csv")
df
# Out:
#       Order Id  Order Date       Ship Mode    Segment        Country  \
# 0            1  2023-03-01    Second Class   Consumer  United States
# 1            2  2023-08-15    Second Class   Consumer  United States
# 2            3  2023-01-10    Second Class  Corporate  United States
# 3            4  2022-06-18  Standard Class   Consumer  United States
# 4            5  2022-07-13  Standard Class   Consumer  United States
# ...        ...         ...             ...        ...            ...
# 9989      9990  2023-02-18    Second Class   Consumer  United States
# 9990      9991  2023-03-17  Standard Class   Consumer  United States
# 9991      9992  2022-08-07  Standard Class   Consumer  United States
# 9992      9993  2022-11-19  Standard Class   Consumer  United States
# 9993      9994  2022-07-17    Second Class   Consumer  United States
#
#                  City       State  Postal Code Region         Category  \
# ...

# %%
# SHOW COLUMNS
df.columns
# Out:
# Index(['Order Id', 'Order Date', 'Ship Mode', 'Segment', 'Country', 'City',
#        'State', 'Postal Code', 'Region', 'Category', 'Sub Category',
#        'Product Id', 'cost price', 'List Price', 'Quantity',
#        'Discount Percent'],
#       dtype='object')

# %%
# COLUMN RENAME
df =df.rename(columns={'Order Id':'order_id','Order Date':'order_date','Ship Mode':'ship_mode','Postal Code':'postal_code','Sub Category':'product_name','Product Id':'product_id','cost price':'cost_price','List Price':'list_price','Discount Percent':'discount_percent','Segment':'segment','Country':'country','City':'city','State':'state','Region':'region','Category':'category','Quantity':'quantity'})
df
# Out:
#       order_id  order_date       ship_mode    segment        country  \
# 0            1  2023-03-01    Second Class   Consumer  United States
# 1            2  2023-08-15    Second Class   Consumer  United States
# 2            3  2023-01-10    Second Class  Corporate  United States
# 3            4  2022-06-18  Standard Class   Consumer  United States
# 4            5  2022-07-13  Standard Class   Consumer  United States
# ...        ...         ...             ...        ...            ...
# 9989      9990  2023-02-18    Second Class   Consumer  United States
# 9990      9991  2023-03-17  Standard Class   Consumer  United States
# 9991      9992  2022-08-07  Standard Class   Consumer  United States
# 9992      9993  2022-11-19  Standard Class   Consumer  United States
# 9993      9994  2022-07-17    Second Class   Consumer  United States
#
#                  city       state  postal_code region         category  \
# ...

# %%
# CHECK DATA TYPES OF COLUMNS
df.dtypes
# Out:
# order_id             int64
# order_date          object
# ship_mode           object
# segment             object
# country             object
# city                object
# state               object
# postal_code          int64
# region              object
# category            object
# product_name        object
# product_id          object
# cost_price           int64
# list_price           int64
# quantity             int64
# discount_percent     int64
# dtype: object

# %%
# CHANGE DATE TYPE
df['order_date'] = pd.to_datetime(df['order_date'])

# %%
# Extract year, month, and day
df['Year'] = df['order_date'].dt.year
df['Month'] = df['order_date'].dt.month
df['Day'] = df['order_date'].dt.day

# %%
df.dtypes
# Out:
# order_id                     int64
# order_date          datetime64[ns]
# ship_mode                   object
# segment                     object
# country                     object
# city                        object
# state                       object
# postal_code                  int64
# region                      object
# category                    object
# product_name                object
# product_id                  object
# cost_price                   int64
# list_price                   int64
# quantity                     int64
# discount_percent             int64
# Year                         int32
# Month                        int32
# Day                          int32
# dtype: object

# %%
# CHECK NULL VALUES
df.isnull().sum()
# Out:
# order_id            0
# order_date          0
# ship_mode           1
# segment             0
# country             0
# city                0
# state               0
# postal_code         0
# region              0
# category            0
# product_name        0
# product_id          0
# cost_price          0
# list_price          0
# quantity            0
# discount_percent    0
# Year                0
# Month               0
# Day                 0
# dtype: int64

# %%
#FILL NA
df=df.fillna(method='ffill')
# Out:
# C:\Users\hraha_8xjyrze\AppData\Local\Temp\ipykernel_10228\1212337889.py:2: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df=df.fillna(method='ffill')

# %%
df.isnull().sum()
# Out:
# order_id            0
# order_date          0
# ship_mode           0
# segment             0
# country             0
# city                0
# state               0
# postal_code         0
# region              0
# category            0
# product_name        0
# product_id          0
# cost_price          0
# list_price          0
# quantity            0
# discount_percent    0
# Year                0
# Month               0
# Day                 0
# dtype: int64

# %%
print(df['ship_mode'].value_counts())
df
# Out:
# ship_mode
# Standard Class    5963
# Second Class      1945
# First Class       1538
# Same Day           543
# Not Available        4
# unknown              1
# Name: count, dtype: int64
#       order_id order_date       ship_mode    segment        country  \
# 0            1 2023-03-01    Second Class   Consumer  United States
# 1            2 2023-08-15    Second Class   Consumer  United States
# 2            3 2023-01-10    Second Class  Corporate  United States
# 3            4 2022-06-18  Standard Class   Consumer  United States
# 4            5 2022-07-13  Standard Class   Consumer  United States
# ...        ...        ...             ...        ...            ...
# 9989      9990 2023-02-18    Second Class   Consumer  United States
# 9990      9991 2023-03-17  Standard Class   Consumer  United States
# 9991      9992 2022-08-07  Standard Class   Consumer  United States
# 9992      9993 2022-11-19  Standard Class   Consumer  United States
# ...

# %%
# CALCULATE DISCOUNT
df['discount']=df['list_price']*(df['discount_percent']/100)

# %%
# CALCULATE SALES PRICE
df['sales_price']=df['list_price']-df['discount']

# %%
# CALCULATE PROFIT
df['profit']=df['sales_price']-df['cost_price']

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_mode', 'segment', 'country', 'city',
#        'state', 'postal_code', 'region', 'category', 'product_name',
#        'product_id', 'cost_price', 'list_price', 'quantity',
#        'discount_percent', 'Year', 'Month', 'Day', 'discount', 'sales_price',
#        'profit'],
#       dtype='object')

# %%
# REMOVE WHITE SPACES
df = df.applymap(lambda x: x.strip() if isinstance(x, str) else x) 

print(df)
# Out:
#       order_id order_date       ship_mode    segment        country  \
# 0            1 2023-03-01    Second Class   Consumer  United States
# 1            2 2023-08-15    Second Class   Consumer  United States
# 2            3 2023-01-10    Second Class  Corporate  United States
# 3            4 2022-06-18  Standard Class   Consumer  United States
# 4            5 2022-07-13  Standard Class   Consumer  United States
# ...        ...        ...             ...        ...            ...
# 9989      9990 2023-02-18    Second Class   Consumer  United States
# 9990      9991 2023-03-17  Standard Class   Consumer  United States
# 9991      9992 2022-08-07  Standard Class   Consumer  United States
# 9992      9993 2022-11-19  Standard Class   Consumer  United States
# 9993      9994 2022-07-17    Second Class   Consumer  United States
#
#                  city       state  postal_code region         category  ...  \
# ...

# %%
df.head(5)
# Out:
#    order_id order_date       ship_mode    segment        country  \
# 0         1 2023-03-01    Second Class   Consumer  United States
# 1         2 2023-08-15    Second Class   Consumer  United States
# 2         3 2023-01-10    Second Class  Corporate  United States
# 3         4 2022-06-18  Standard Class   Consumer  United States
# 4         5 2022-07-13  Standard Class   Consumer  United States
#
#               city       state  postal_code region         category  ...  \
# 0        Henderson    Kentucky        42420  South        Furniture  ...
# 1        Henderson    Kentucky        42420  South        Furniture  ...
# 2      Los Angeles  California        90036   West  Office Supplies  ...
# 3  Fort Lauderdale     Florida        33311  South        Furniture  ...
# 4  Fort Lauderdale     Florida        33311  South  Office Supplies  ...
#
#   cost_price list_price  quantity  discount_percent  Year  Month  Day  \
# ...

# %%
# SEPERATE TWO TABLE
df1=df.iloc[0:,0:12]
df1
# Out:
#       order_id order_date       ship_mode    segment        country  \
# 0            1 2023-03-01    Second Class   Consumer  United States
# 1            2 2023-08-15    Second Class   Consumer  United States
# 2            3 2023-01-10    Second Class  Corporate  United States
# 3            4 2022-06-18  Standard Class   Consumer  United States
# 4            5 2022-07-13  Standard Class   Consumer  United States
# ...        ...        ...             ...        ...            ...
# 9989      9990 2023-02-18    Second Class   Consumer  United States
# 9990      9991 2023-03-17  Standard Class   Consumer  United States
# 9991      9992 2022-08-07  Standard Class   Consumer  United States
# 9992      9993 2022-11-19  Standard Class   Consumer  United States
# 9993      9994 2022-07-17    Second Class   Consumer  United States
#
#                  city       state  postal_code region         category  \
# 0           Henderson    Kentucky        42420  South        Furniture
# ...

# %%
df2=df.iloc[0:,11:22]
df2
# Out:
#            product_id  cost_price  list_price  quantity  discount_percent  \
# 0     FUR-BO-10001798         240         260         2                 2
# 1     FUR-CH-10000454         600         730         3                 3
# 2     OFF-LA-10000240          10          10         2                 5
# 3     FUR-TA-10000577         780         960         5                 2
# 4     OFF-ST-10000760          20          20         2                 5
# ...               ...         ...         ...       ...               ...
# 9989  FUR-FU-10001889          30          30         3                 4
# 9990  FUR-FU-10000747          70          90         2                 4
# 9991  TEC-PH-10003645         220         260         2                 2
# 9992  OFF-PA-10004041          30          30         4                 3
# 9993  OFF-AP-10002684         210         240         2                 3
#
#       Year  Month  Day  discount  sales_price  profit
# ...

# %%
import psycopg2
connection=psycopg2.connect(
    host="localhost",
    user="postgres",
    password="kuma"
)
mediater=connection.cursor()
mediater.execute("select version()")
version_output=mediater.fetchone()
print(version_output)
# Out:
# ('PostgreSQL 16.6, compiled by Visual C++ build 1942, 64-bit',)

# %%
from sqlalchemy import create_engine
import pandas as pd

host = "localhost"
user = "postgres"
password = "kuma"
database = "first"

engine = create_engine(f"postgresql://{user}:{password}@{host}/{database}")

data = pd.read_csv('C:\\Users\\hraha_8xjyrze\\Downloads\\archive\\orders.csv')

table_name = "orders"

data.to_sql(table_name,engine,if_exists="replace",index=False) #['fail,replace,append']

print("successfully inserted")
# Out:
# successfully inserted

# %%
df2=df.iloc[0:,11:22]
df2
# Out:
#            product_id  cost_price  list_price  quantity  discount_percent  \
# 0     FUR-BO-10001798         240         260         2                 2
# 1     FUR-CH-10000454         600         730         3                 3
# 2     OFF-LA-10000240          10          10         2                 5
# 3     FUR-TA-10000577         780         960         5                 2
# 4     OFF-ST-10000760          20          20         2                 5
# ...               ...         ...         ...       ...               ...
# 9989  FUR-FU-10001889          30          30         3                 4
# 9990  FUR-FU-10000747          70          90         2                 4
# 9991  TEC-PH-10003645         220         260         2                 2
# 9992  OFF-PA-10004041          30          30         4                 3
# 9993  OFF-AP-10002684         210         240         2                 3
#
#       Year  Month  Day  discount  sales_price  profit
# ...

# %%
table_name = "df2"

df2.to_sql(table_name,engine,if_exists="replace",index=False) #['fail,replace,append']

print("successfully inserted")
# Out:
# successfully inserted

# %%
df1=df.iloc[0:,0:12]
df1
# Out:
#       order_id order_date       ship_mode    segment        country  \
# 0            1 2023-03-01    Second Class   Consumer  United States
# 1            2 2023-08-15    Second Class   Consumer  United States
# 2            3 2023-01-10    Second Class  Corporate  United States
# 3            4 2022-06-18  Standard Class   Consumer  United States
# 4            5 2022-07-13  Standard Class   Consumer  United States
# ...        ...        ...             ...        ...            ...
# 9989      9990 2023-02-18    Second Class   Consumer  United States
# 9990      9991 2023-03-17  Standard Class   Consumer  United States
# 9991      9992 2022-08-07  Standard Class   Consumer  United States
# 9992      9993 2022-11-19  Standard Class   Consumer  United States
# 9993      9994 2022-07-17    Second Class   Consumer  United States
#
#                  city       state  postal_code region         category  \
# 0           Henderson    Kentucky        42420  South        Furniture
# ...

# %%
table_name = "df1"

df1.to_sql(table_name,engine,if_exists="replace",index=False) #['fail,replace,append']

print("successfully inserted")
# Out:
# successfully inserted

# %%
table_name = "df"

df.to_sql(table_name,engine,if_exists="replace",index=False) #['fail,replace,append']

print("successfully inserted")
# Out:
# successfully inserted
